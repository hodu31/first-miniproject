# %% [markdown]
# ## 2019

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import folium
import json
import platform
plt.rc("font", family="Malgun Gothic")
plt.rcParams["axes.unicode_minus"] = False

# %%
# 변경할 폴더 경로
folder_path = "./2019_2022_강원도_카테고리별_관광인프라/중심관광지"
# 폴더 내의 파일 목록을 가져옴
file_list = os.listdir(folder_path)
# 데이터프레임들이 들어갈 리스트 만들기
df=[]

df_2019=pd.DataFrame()
### 18->16->15
for i in range(0,18,1):
    # 파일명에서 시군명 추출
    sigoon=file_list[i][4:7]
    # 각 파일경로 지정
    file_path=("./2019_2022_강원도_카테고리별_관광인프라/중심관광지/2022{}중심 관광지.csv".format(sigoon))
    # df에 각각의 데이터프레임명 추가하기
    df.append(pd.read_csv(file_path, encoding="euc-kr"))
    # 데이터프레임에 도명/시군명 컬럼 추가
    #df[i]["도명"]="강원도"
    #df[i]["시군명"]=sigoon
    # "중심카테고리 명_대" 데이터 삭제
    del(df[i]["중심카테고리 명_대"])

# %%
lst_area = []
lst_area = df[0]["분류"].unique()

# %%
lst_file = []
for i in range(18):
     lst_file.append(df[i]["분류"].unique())

# %%
lst_file[0][1]
# Out:
# '자연관광'

# %%
lst_area
# Out:
# array(['쇼핑', '자연관광', '문화관광', '숙박', '역사관광', '기타관광', '레저스포츠', '체험관광'],
#       dtype=object)

# %%
a= []
b = []
for i in range(18):
    for p in range(len(lst_file[i])):
        condition = df[i]["분류"] == lst_file[i][p]
        a.append(df[i][condition == True].reset_index(drop = True))
    b.append(a)

# %%
b[0][1]
# b[지역설정][분류설정]
# Out:
#     중심 POI X 좌표  중심 POI Y 좌표      관광지명                   주소    분류   순위
# 0      128.9078      37.8055      경포해변               강원 강릉시  자연관광    2
# 1      128.9473      37.7731      안목해변  강원 강릉시 창해로14번길 20-1  자연관광    4
# 2      128.9176      37.7966      강문해변               강원 강릉시  자연관광    7
# 3      128.8299      37.8920      주문진항   강원 강릉시 해안로 1758-14  자연관광    9
# 4      129.0345      37.6908     정동진해변     강원 강릉시 정동역길 17-0  자연관광   15
# 5      128.8192      37.9110     주문진해변      강원 강릉시 주문북로 0-0  자연관광   21
# 6      128.8993      37.8125     사근진해변               강원 강릉시  자연관광   24
# 7      128.9377      37.7801      송정해변  강원 강릉시 송정길30번안길 0-0  자연관광   26
# 8      128.8453      37.8691      영진해변               강원 강릉시  자연관광   32
# 9      128.9522      37.7705       강릉항  강원 강릉시 창해로14번길 51-4  자연관광   33
# 10     128.8785      37.8300      사천해변       강원 강릉시 해안로 0-0  자연관광   36
# 11     129.0532      37.6651       심곡항       강원 강릉시 헌화로 0-0  자연관광   40
# 12     128.9023      37.7968       경포호       강원 강릉시 경포로 0-0  자연관광   42
# 13     128.8932      37.8172      순긋해변               강원 강릉시  자연관광   49
# 14     128.8609      37.6927   강릉솔향수목원    강원 강릉시 수목원길 156-0  자연관광   54
# 15     128.9549      37.7643     남항진해변               강원 강릉시  자연관광   56
# 16     128.8784      37.8365       사천항   강원 강릉시 진리해변길 68-23  자연관광   57
# 17     128.8544      37.8585      연곡해변               강원 강릉시  자연관광   60
# 18     129.0494      37.6281      옥계해변               강원 강릉시  자연관광   61
# 19     129.0509      37.6524       금진항     강원 강릉시 헌화로 460-0  자연관광   62
# 20     129.0449      37.6364      금진해변     강원 강릉시 헌화로 271-0  자연관광   63
# 21     128.8165      37.9129      향호해변               강원 강릉시  자연관광   65
# 22     128.9896      37.7353       안인항     강원 강릉시 안인진길 43-0  자연관광   72
# 23     128.8308      37.9046       소돌항               강원 강릉시  자연관광   74
# 24     128.8251      37.9069      소돌해변               강원 강릉시  자연관광   75
# 25     128.8740      37.8428     사천진해변               강원 강릉시  자연관광   76
# 26     128.7882      37.7129  대관령자연휴양림    강원 강릉시 삼포암길 133-0  자연관광   77
# 27     128.8481      37.8675       영진항       강원 강릉시 해안로 0-0  자연관광   85
# 28     128.9085      37.8035    경포도립공원               강원 강릉시  자연관광   89
# 29     128.7054      37.8132     소금강계곡               강원 강릉시  자연관광   95
# 30     129.0164      37.7045      등명해변               강원 강릉시  자연관광   97
# 31     128.9842      37.7419      염전해변               강원 강릉시  자연관광  100

# %%
# Out:
# 32

# %%
import folium

color_list = ['#0a676c', '#70a3bd', '#c16e2e', "#89cff0", "#790b9e", "#e51111", "#6c78d7", "#403157"]

gw_list = []
gw_map = folium.Map(location=[37.882531, 127.7291452], tiles="CartoDB positron", zoom_start=7)

layer_control = folium.LayerControl()

for i in range(18): 
    for p in range(len(lst_file[i])):
        layer = folium.FeatureGroup(name=f"Layer {i+1}" + ":" + "{}".format(lst_file[i][p]))
        for x in range(len(b[i][p])):
            lat = b[i][p].loc[x, "중심 POI Y 좌표"]
            lng = b[i][p].loc[x, "중심 POI X 좌표"]
            marker_weight = 5
            colorcolor = color_list[p]
            folium.CircleMarker(location=[lat, lng],
                                fill_color=colorcolor,
                                fill_opacity=1,
                                color=colorcolor,
                                weight=marker_weight,
                                radius=marker_weight).add_to(layer)

        layer.add_to(gw_map)

layer_control.add_to(gw_map)

gw_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18efefa397fe42483f516587fef7b69d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18efefa397fe42483f516587fef7b69d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18efefa397fe42483f516587fef7b69d = L.map(
#                 &quot;map_18efefa397fe42483f516587fef7b69d&quot;,
#                 {
#                     center: [37.882531, 127.7291452],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8908e3b3140271a901af320e5877223c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_18efefa397fe42483f516587fef7b69d);
#
#
#             var feature_group_08e16b3b53c3a0e53b57844b31731404 = L.featureGroup(
#                 {}
#             ).addTo(map_18efefa397fe42483f516587fef7b69d);
#
#
#             var circle_marker_41a87cc8af75533dd8d3dd85d45f9d1d = L.circleMarker(
#                 [37.754, 128.8986],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0a676c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0a676c&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(feature_group_08e16b3b53c3a0e53b57844b31731404);
#
#
#             var circle_marker_4644ad52cf86176df6f98b1ba0a452ff = L.circleMarker(
#                 [37.891, 128.8277],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0a676c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0a676c&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(feature_group_08e16b3b53c3a0e53b57844b31731404);
#
#
#             var circle_marker_59e44818497ae4cd523375b7279511ee = L.circleMarker(
#                 [37.7705, 128.9226],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0a676c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0a676c&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(feature_group_08e16b3b53c3a0e53b57844b31731404);
#
#
#             var circle_marker_e6857fea5696ea41d2b064259ac8d0f9 = L.circleMarker(
#                 [37.7558, 128.8986],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0a676c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0a676c&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(feature_group_08e16b3b53c3a0e53b57844b31731404);
#
#
#             var circle_marker_4b0bb97614b9fc2ce0e601ba926bb65e = L.circleMarker(
#                 [37.8917, 128.8293],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0a676c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0a676c&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(feature_group_08e16b3b53c3a0e53b57844b31731404);
#
#
#             var circle_marker_c2adf6e00ca85d451ac4f6decc913d35 = L.circleMarker(
#                 [37.8935, 128.8297],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0a676c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0a676c&quot;, &quot;fillOpacity&quot;: 1,

# %%
import folium

color_list = ['#0a676c', '#70a3bd', '#c16e2e', "#89cff0", "#790b9e", "#e51111", "#6c78d7", "#403157"]

gw_list = []
gw_map = folium.Map(location=[37.882531, 127.7291452], tiles="CartoDB positron", zoom_start=7)

  # Create a FeatureGroup object

layer_control = folium.LayerControl()

for i in range(18): 
    for p in range(len(lst_file[i])):
        layer = folium.FeatureGroup(name=f"Layer {i+1}" + ":" + "{}".format(lst_file[i][p]))
        for x in range(len(b[i][p])):
            lat = b[i][p].loc[x, "중심 POI Y 좌표"]
            lng = b[i][p].loc[x, "중심 POI X 좌표"]
            marker_weight = 5
            colorcolor = color_list[p]
            folium.CircleMarker(location=[lat, lng],
                                fill_color=colorcolor,
                                fill_opacity=1,
                                color=colorcolor,
                                weight=marker_weight,
                                radius=marker_weight).add_to(layer)

        layer.add_to(gw_map)

layer_control.add_to(gw_map)

    
gw_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80c5173238d462050ec0cff980e714f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80c5173238d462050ec0cff980e714f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80c5173238d462050ec0cff980e714f1 = L.map(
#                 &quot;map_80c5173238d462050ec0cff980e714f1&quot;,
#                 {
#                     center: [37.882531, 127.7291452],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8de4ec25938bd4b0fc12e8c959129dc9 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_80c5173238d462050ec0cff980e714f1);
#
#
#             var feature_group_e55f3d9e5d2ea061e829698e5d40c596 = L.featureGroup(
#                 {}
#             ).addTo(map_80c5173238d462050ec0cff980e714f1);
#
#
#             var circle_marker_40cdab9b3b1ec72dd0c41a775e21bd7a = L.circleMarker(
#                 [37.754, 128.8986],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0a676c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0a676c&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(feature_group_e55f3d9e5d2ea061e829698e5d40c596);
#
#
#             var circle_marker_ce6b1adb19e9c9e14b7b6d260750ccd6 = L.circleMarker(
#                 [37.891, 128.8277],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0a676c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0a676c&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(feature_group_e55f3d9e5d2ea061e829698e5d40c596);
#
#
#             var circle_marker_f3db7c66c6d7e89526a2a8fd538482f0 = L.circleMarker(
#                 [37.7705, 128.9226],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0a676c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0a676c&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(feature_group_e55f3d9e5d2ea061e829698e5d40c596);
#
#
#             var circle_marker_7f8b369642339216f871f0f7b426adc9 = L.circleMarker(
#                 [37.7558, 128.8986],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0a676c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0a676c&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(feature_group_e55f3d9e5d2ea061e829698e5d40c596);
#
#
#             var circle_marker_aeedb264a30e0ff276320e33cc0d30f1 = L.circleMarker(
#                 [37.8917, 128.8293],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0a676c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0a676c&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(feature_group_e55f3d9e5d2ea061e829698e5d40c596);
#
#
#             var circle_marker_66fae4c506c222092c385e6f02e366ab = L.circleMarker(
#                 [37.8935, 128.8297],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0a676c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0a676c&quot;, &quot;fillOpacity&quot;: 1,

# %%
import folium

color_list = ['#0a676c', '#70a3bd', '#c16e2e', "#89cff0", "#790b9e", "#e51111", "#6c78d7", "#403157"]
gw_list = []
gw_map = folium.Map(location=[37.882531, 127.7291452], tiles="CartoDB positron", zoom_start=7)

layer_control = folium.LayerControl()

for ui in range(18):
    for idx, df in enumerate(df_area):
        layer = folium.FeatureGroup(name=f"Layer {idx+1}" +":"+ "{}".format(lst_name[idx]) )

        for i in range(len(df)):
            lat = df.loc[i, "중심 POI Y 좌표"]
            lng = df.loc[i, "중심 POI X 좌표"]
            marker_weight = 5
            colorcolor = color_list[idx]

            folium.CircleMarker(location=[lat, lng],
                                fill_color=colorcolor,
                                fill_opacity=1,
                                color=colorcolor,
                                weight=marker_weight,
                                radius=marker_weight).add_to(layer)

        layer.add_to(gw_map)

    layer_control.add_to(gw_map)

    gw_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 11
#       9 for ui in range(18):
#      10     for idx, df in enumerate(b):
# ---> 11         layer = folium.FeatureGroup(name=f"Layer {idx+1}" +":"+ "{}".format(lst_name[idx]) )
#      13         for i in range(len(df)):
#      14             lat = df.loc[i, "중심 POI Y 좌표"]
#
# NameError: name 'lst_name' is not defined

# %%
color_list = ['#0a676c', '#70a3bd', '#c16e2e', "#89cff0", "#790b9e", "#e51111", "#6c78d7", "#403157"]
gw_list = []
gw_map = folium.Map(location=[37.882531, 127.7291452], tiles="CartoDB positron", zoom_start=7)

layer_control = folium.LayerControl()

# 변경할 폴더 경로
folder_path = "./2019_2022_강원도_카테고리별_관광인프라/중심관광지"
# 폴더 내의 파일 목록을 가져옴
file_list = os.listdir(folder_path)

# 데이터프레임들이 들어갈 리스트 만들기
dfs = []

df_2019 = pd.DataFrame()
### 18->16->15
for f in range(0, 18, 1):
    # 파일명에서 시군명 추출
    sigoon = file_list[f][4:7]
    # 각 파일경로 지정
    file_path = ("./2019_2022_강원도_카테고리별_관광인프라/중심관광지/2019{}중심 관광지.csv".format(sigoon))
    # df에 각각의 데이터프레임명 추가하기
    dfs.append(pd.read_csv(file_path, encoding="euc-kr"))
    # 데이터프레임에 도명/시군명 컬럼 추가
    # dfs[i]["도명"]="강원도"
    # dfs[i]["시군명"]=sigoon
    # "중심카테고리 명_대" 데이터 삭제
    del (dfs[f]["중심카테고리 명_대"])

    for idx, oe in enumerate(df_area):
        layer = folium.FeatureGroup(name=f"Layer {idx+1}" +":"+ "{}".format(lst_name[idx]) )

        for i in range(len(df)):
            lat = df.loc[i, "중심 POI Y 좌표"]
            lng = df.loc[i, "중심 POI X 좌표"]
            marker_weight = 5
            colorcolor = color_list[idx]

            folium.CircleMarker(location=[lat, lng],
                                fill_color=colorcolor,
                                fill_opacity=1,
                                color=colorcolor,
                                weight=marker_weight,
                                radius=marker_weight).add_to(layer)

        layer.add_to(gw_map)


layer_control.add_to(gw_map)

gw_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 30
#      24 # 데이터프레임에 도명/시군명 컬럼 추가
#      25 # dfs[i]["도명"]="강원도"
#      26 # dfs[i]["시군명"]=sigoon
#      27 # "중심카테고리 명_대" 데이터 삭제
#      28 del (dfs[f]["중심카테고리 명_대"])
# ---> 30 for idx, oe in enumerate(df_area):
#      31     layer = folium.FeatureGroup(name=f"Layer {idx+1}" +":"+ "{}".format(lst_name[idx]) )
#      33     for i in range(len(df)):
#
# NameError: name 'df_area' is not defined

# %%
df
# Out:
# [    중심 POI X 좌표  중심 POI Y 좌표       관광지명                   주소    분류   순위
#  0      128.8986      37.7540     강릉중앙시장      강원 강릉시 금성로 21-0    쇼핑    1
#  1      128.9078      37.8055       경포해변               강원 강릉시  자연관광    2
#  2      128.9074      37.7917  아르떼뮤지엄/강릉    강원 강릉시 난설헌로 131-0  문화관광    3
#  3      128.9473      37.7731       안목해변  강원 강릉시 창해로14번길 20-1  자연관광    4
#  4      128.9209      37.7911    세인트존스호텔     강원 강릉시 창해로 307-0    숙박    5
#  ..          ...          ...        ...                  ...   ...  ...
#  95     128.8973      37.7560       월화거리    강원 강릉시 경강로 2111-0  문화관광   96
#  96     129.0164      37.7045       등명해변               강원 강릉시  자연관광   97
#  97     128.8954      37.7722     강릉아트센터   강원 강릉시 종합운동장길 84-0  문화관광   98
#  98     128.9221      37.7899    파라다이스모텔     강원 강릉시 창해로 291-0    숙박   99
#  99     128.9842      37.7419       염전해변               강원 강릉시  자연관광  100
#
#  [100 rows x 6 columns],
#      중심 POI X 좌표  중심 POI Y 좌표         관광지명                   주소    분류   순위
#  0      128.4938      38.2105      소노캄/델피노  강원 고성군 미시령옛길 1153-0    숙박    1
#  1      128.5533      38.2764      아야진해수욕장               강원 고성군  자연관광    2
#  2      128.5723      38.2428  켄싱턴리조트/설악비치   강원 고성군 동해대로 4800-0    숙박    3
#  3      128.4907      38.2283  켄싱턴리조트/설악밸리     강원 고성군 신평골길 8-25    숙박    4
#  4      128.5278      38.3309        송지호해변     강원 고성군 오호2길 24-0  자연관광    5
#  ..          ...          ...          ...                  ...   ...  ...
#  95     128.5514      38.2699        호텔파티오   강원 고성군 동해대로 5180-0    숙박   96
#  96     128.5669      38.2500         탑하우스      강원 고성군 토성로 28-0    숙박   97
#  97     128.5487      38.3023        문암1리항      강원 고성군 문암항길 0-0  기타관광   98
#  98     128.4053      38.5435    명파해변오토캠핑장     강원 고성군 명파4길 47-0    숙박   99
#  99     128.4619      38.4248          반암항               강원 고성군  자연관광  100
#
#  [100 rows x 6 columns],
#      중심 POI X 좌표  중심 POI Y 좌표      관광지명                   주소    분류   순위
#  0      129.1599      37.4790      촛대바위               강원 동해시  기타관광    1
#  1      129.1124      37.5498       묵호항               강원 동해시  자연관광    2
#  2      129.0900      37.5937    망상해수욕장  강원 동해시 동해대로 6270-21  자연관광    3
#  3      129.1144      37.5519    묵호항어시장      강원 동해시 일출로 60-0    쇼핑    4
#  4      129.1101      37.5173  천곡황금박쥐동굴      강원 동해시 동굴로 50-0  자연관광    5
#  ..          ...          ...       ...                  ...   ...  ...
#  95     129.1169      37.5687      신비호텔     강원 동해시 일출로 309-1    숙박   96
#  96     129.0788      37.5967    홀리데이민박     강원 동해시 석두골길 9-10    숙박   97
#  97     129.1113      37.4928      렉스모텔     강원 동해시 효자로 705-0    숙박   98
#  98     129.1113      37.4951      에덴모텔   강원 동해시 동해대로 5032-1    숙박   99
#  99     129.0932      37.5860     초콜릿모텔  강원 동해시 동해대로 6199-30    숙박  100
#
#  [100 rows x 6 columns],
#      중심 POI X 좌표  중심 POI Y 좌