# %%
# import 해오기
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import folium
import json
import platform
plt.rc("font", family="Malgun Gothic")
plt.rcParams["axes.unicode_minus"] = False

# %%
# 위치한 폴더 경로
file_path = "./강원도 카페 음식 생활 시설 수 .xlsx"
df = pd.read_excel(file_path)

# %%
df = df[:18].copy()

# %%
df
# Out:
#    Unnamed: 0      카페  카페_비율(%)  카페_순위     음식점  음식점_비율(%)  음식점_순위  생활문화시설
# 0         강릉시  1300.0  0.172918    3.0  4666.0   0.154652     3.0   354.0  \
# 1         고성군   163.0  0.021681   13.0   672.0   0.022273    16.0   168.0
# 2         동해시   367.0  0.048816    5.0  1650.0   0.054688     5.0   150.0
# 3         삼척시   295.0  0.039239    7.0  1339.0   0.044380     7.0    92.0
# 4         속초시   493.0  0.065576    4.0  2149.0   0.071227     4.0   150.0
# 5         양구군    83.0  0.011040   17.0   434.0   0.014385    18.0    83.0
# 6         양양군   175.0  0.023277   12.0   824.0   0.027311    11.0    88.0
# 7         영월군   157.0  0.020883   14.0   697.0   0.023102    14.0    81.0
# 8         원주시  1608.0  0.213887    1.0  5840.0   0.193563     1.0    55.0
# 9         인제군   135.0  0.017957   16.0   831.0   0.027543    10.0   206.0
# 10        정선군   235.0  0.031258    9.0   884.0   0.029300     9.0    51.0
# 11        철원군   178.0  0.023677   11.0   800.0   0.026516    13.0    98.0
# 12        춘천시  1307.0  0.173849    2.0  4715.0   0.156276     2.0   333.0
# 13        태백시   152.0  0.020218   15.0   808.0   0.026781    12.0    30.0
# 14        평창군   272.0  0.036180    8.0  1202.0   0.039840     8.0    80.0
# 15        홍천군   310.0  0.041234    6.0  1443.0   0.047827     6.0   144.0
# 16        화천군    80.0  0.010641   18.0   528.0   0.017500    17.0    42.0
# 17        횡성군   208.0  0.027667   10.0   689.0   0.022836    15.0    43.0
#
#     생활문화시설_비율(%)  생활문화시설_순위
# 0       0.157473        1.0
# 1       0.074733        4.0
# 2       0.066726        5.0
# 3       0.040925        9.0
# 4       0.066726        5.0
# 5       0.036922       11.0
# 6       0.039146       10.0
# 7       0.036032       12.0
# 8       0.024466       14.0
# 9       0.091637        3.0
# 10      0.022687       15.0
# 11      0.043594        8.0
# 12      0.148132        2.0
# 13      0.013345       18.0
# 14      0.035587       13.0
# 15      0.064057        7.0
# 16      0.018683       17.0
# 17      0.019128       16.0

# %%
plt.figure(figsize=(20,10))
plt.title("강원도 지역별 카페 수")
plt.bar(df["Unnamed: 0"], df["카페"])
# Out:
# <BarContainer object of 18 artists>

# %%
plt.figure(figsize=(20,10))
plt.title("강원도 지역별 음식점 수")
plt.bar(df["Unnamed: 0"], df["음식점"])
# Out:
# <BarContainer object of 18 artists>
